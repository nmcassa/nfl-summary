# %%
#!pip install matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('axes', axisbelow=True)

# %%
db = pd.read_csv("data/play_by_play_2023.csv")
db.describe()
# Out:
# /var/folders/jq/z17b57lx55q8y9sr8pv9c4140000gn/T/ipykernel_51304/1542154189.py:1: DtypeWarning: Columns (45,179,180,182,183,189,190,197,198,203,204,205,206,218,219,220,222,224,226,253,254,255,260,262,263,283,284,332) have mixed types. Specify dtype option on import or set low_memory=False.
#   db = pd.read_csv("data/play_by_play_2023.csv")
#             play_id   old_game_id          week  yardline_100  \
# count  49665.000000  4.966500e+04  49665.000000  46205.000000
# mean    2179.316984  2.023197e+09      9.931219     48.958814
# std     1266.910386  2.698698e+05      5.601549     24.215457
# min        1.000000  2.023091e+09      1.000000      1.000000
# 25%     1093.000000  2.023101e+09      5.000000     32.000000
# 50%     2165.000000  2.023111e+09     10.000000     51.000000
# 75%     3249.000000  2.023122e+09     15.000000     70.000000
# max     5340.000000  2.024021e+09     22.000000     99.000000
#
#        quarter_seconds_remaining  half_seconds_remaining  \
# ...

# %%
db.columns
# Out:
# Index(['play_id', 'game_id', 'old_game_id', 'home_team', 'away_team',
#        'season_type', 'week', 'posteam', 'posteam_type', 'defteam',
#        ...
#        'out_of_bounds', 'home_opening_kickoff', 'qb_epa', 'xyac_epa',
#        'xyac_mean_yardage', 'xyac_median_yardage', 'xyac_success', 'xyac_fd',
#        'xpass', 'pass_oe'],
#       dtype='object', length=372)

# %%
clean = db[['home_team', 'away_team', 'week', 'total_home_score', 'yrdln', 'yards_gained', 'posteam', 'ydstogo', 'time', 'ep', 'epa']]
clean.head()
# Out:
#   home_team away_team  week  total_home_score   yrdln  yards_gained posteam  \
# 0       WAS       ARI     1                 0  ARI 35           NaN     NaN
# 1       WAS       ARI     1                 0  ARI 35           0.0     WAS
# 2       WAS       ARI     1                 0  WAS 25           3.0     WAS
# 3       WAS       ARI     1                 0  WAS 28           6.0     WAS
# 4       WAS       ARI     1                 0  WAS 34           2.0     WAS
#
#    ydstogo   time        ep       epa
# 0        0  15:00  1.474098  0.000000
# 1        0  15:00  1.474098  0.000000
# 2       10  15:00  1.474098 -0.336103
# 3        7  14:30  1.137994  0.703308
# 4        1  13:55  1.841302  0.469799

# %%
clean = clean[clean['home_team'] == 'LV']
clean
# Out:
#       home_team away_team  week  total_home_score   yrdln  yards_gained  \
# 8203         LV       PIT     3                 0   LV 35           NaN
# 8204         LV       PIT     3                 0   LV 35           0.0
# 8205         LV       PIT     3                 0  PIT 25           5.0
# 8206         LV       PIT     3                 0  PIT 30           4.0
# 8207         LV       PIT     3                 0  PIT 34           0.0
# ...         ...       ...   ...               ...     ...           ...
# 45722        LV       DEN    18                27  DEN 46          11.0
# 45723        LV       DEN    18                27   LV 43           0.0
# 45724        LV       DEN    18                27   LV 17          -1.0
# 45725        LV       DEN    18                27   LV 16          -1.0
# 45726        LV       DEN    18                27     NaN           NaN
#
#       posteam  ydstogo   time        ep       epa
# 8203      NaN        0  15:00  1.008251  0.000000
# ...
